# %% [markdown]
# Data Dictionary for initial dataframe (data2.csv)
#
# * **Job Title**: contains the title of the job position that is being advertise
# * **Job Info**: contains information about the job, such as whether it is full-time or part-time, and whether it is a job or an internship
# * **Company Name**: contains the name of the company that is offering the job
# * **Company Location**: contains the location of the company, including the city and state
# * **Employees**: contains information about the size of the company, such as the number of employees
# * **Industry**: contains the industry in which the company operates
# * **Headquarters**: contains the location of the company's headquarters
# * **Application deadline**: contains the date and time by which job applications must be submitted
# * **Posted date**: contains the date on which the job was posted
# * **Location type**: contains information about the type of location where the job is located, such as whether it is on-site or remote
# * **US work authorization**: contains information about whether the company requires candidates to have US work authorization
# * **Estimated pay**: contains information about the estimated pay for the job position.
# * **Seasonal role**: contains information about the working perid for sesonal roles.
# * **Company division**: contains information about the division of the company that is offering the job
# * **Work study**: contains information about whether the job is a work study program

# %% [markdown]
# Important libraries

# %%
import pandas as pd
import numpy as np
import math

# %% [markdown]
# Read data from Exel file and create DataFrame for future analysis

# %%
df = pd.read_csv("data2.csv")
df_modify = df.copy()

# %% [markdown]
# Explore initial datafram

# %%
df_modify.head()
# Out:
#                                            Job Title                Job Info  \
# 0                  Entry Level Insurance Underwriter         Full-Time ∙ Job
# 1                                        Internships  Full-Time ∙ Internship
# 2  Blood Bank Associate Technical Support Specialist         Full-Time ∙ Job
# 3     Lab/Mic Associate Technical Support Specialist         Full-Time ∙ Job
# 4  Computer Science Intern - Online Computer Scie...  Part-Time ∙ Internship
#
#                     Company Name  \
# 0  Auto-Owners Insurance Company
# 1  Auto-Owners Insurance Company
# 2              SCC Soft Computer
# 3              SCC Soft Computer
# 4                   Coding4Youth
#
#                                     Company Location        Employees  \
# 0  Lakeland, FL\nIrmo, SC\nForest, VA\nLexington,...   5,000 - 10,000
# 1  Lakeland, FL\nIrmo, SC\nCharlotte, NC\nForest,...   5,000 - 10,000
# 2                                     Clearwater, FL      250 - 1,000
# 3                                     Clearwater, FL      250 - 1,000
# 4  Atlanta, GA\nHouston, TX\nPhiladelphia, PA\nCh...  10,000 - 25,000
#
#               Industry    Headquarters Application deadline Posted date  \
# 0            Insurance     Lansing, MI       4/4/2023 15:30   13-Jul-16
# 1            Insurance     Lansing, MI       4/4/2023 15:30   13-Jul-16
# 2  Internet & Software  Clearwater, FL       3/13/2023 0:00   22-Aug-16
# 3  Internet & Software  Clearwater, FL       3/13/2023 0:00   22-Aug-16
# 4      Other Education    San Jose, CA      9/29/2050 21:31   19-Sep-16
#
#   Location type US work authorization    Estimated pay       Seasonal role  \
# 0       On-site              Required              NaN                 NaN
# 1       On-site              Required              NaN                 NaN
# 2       On-site              Required  $19.00 per hour                 NaN
# 3       On-site              Required  $18.00 per hour                 NaN
# 4        Remote              Required  $20.00 per hour  (6/5/17 - 9/12/90)
#
#   Company division Work study
# 0              NaN        NaN
# 1              NaN        NaN
# 2              NaN        NaN
# 3              NaN        NaN
# 4              NaN        NaN

# %%
df_modify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19447 entries, 0 to 19446
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Job Title              19447 non-null  object
#  1   Job Info               19447 non-null  object
#  2   Company Name           19447 non-null  object
#  3   Company Location       19447 non-null  object
#  4   Employees              19447 non-null  object
#  5   Industry               19447 non-null  object
#  6   Headquarters           19442 non-null  object
#  7   Application deadline   19447 non-null  object
#  8   Posted date            19447 non-null  object
#  9   Location type          19447 non-null  object
#  10  US work authorization  19244 non-null  object
#  11  Estimated pay          11334 non-null  object
#  12  Seasonal role          4530 non-null   object
#  13  Company division       3220 non-null   object
#  14  Work study             1 non-null      object
# dtypes: object(15)
# memory usage: 2.2+ MB

# %%
df_modify.shape
# Out:
# (19447, 15)

# %%
df_modify.columns
# Out:
# Index(['Job Title', 'Job Info', 'Company Name', 'Company Location',
#        'Employees', 'Industry', 'Headquarters', 'Application deadline',
#        'Posted date', 'Location type', 'US work authorization',
#        'Estimated pay', 'Seasonal role', 'Company division', 'Work study'],
#       dtype='object')

# %% [markdown]
# ***STEP 1: DATA MODIFICATION***

# %% [markdown]
# Application deadline/ Post date

# %%
# Convert 'Application deadline' column to datetime format
df_modify['Application deadline'] = pd.to_datetime(df_modify['Application deadline'])

# Convert 'Posted date' column to datetime format
df_modify['Posted date'] = pd.to_datetime(df_modify['Posted date'])

# Extract the date and time components from 'Application deadline' column and create new columns
df_modify['Application deadline (date)'] = df_modify['Application deadline'].dt.date
df_modify['Application deadline (time)'] = df_modify['Application deadline'].dt.time

# Calculate the time difference between 'Application deadline (date)' and 'Posted date' columns and create a new column 'Application Window'
df_modify['Application Window (weeks)'] = pd.to_datetime(df_modify['Application deadline (date)']) - df_modify['Posted date']
# Convert 'Application Window' from timedelta64 to int and show in weeks
df_modify['Application Window (weeks)'] = df_modify['Application Window (weeks)'].dt.days // 7

# Convert 'Application deadline (date)' column to datetime format
df_modify['Application deadline (date)'] = pd.to_datetime(df_modify['Application deadline (date)'])

# Drop 'Application deadline' column since we don't need it anymore
df_modify.drop('Application deadline', axis=1, inplace=True)

# %%
df_modify
# Out:
#                                                Job Title  \
# 0                      Entry Level Insurance Underwriter
# 1                                            Internships
# 2      Blood Bank Associate Technical Support Specialist
# 3         Lab/Mic Associate Technical Support Specialist
# 4      Computer Science Intern - Online Computer Scie...
# ...                                                  ...
# 19442                   Coaching Assistant - Summer camp
# 19443                       Videographer/Content Creator
# 19444                 Talent Acquisition Intern - Remote
# 19445                       Camp Counselor - Summer 2023
# 19446  Outdoor Adventure & Ropes Instructor - Summer ...
#
#                      Job Info                   Company Name  \
# 0             Full-Time ∙ Job  Auto-Owners Insurance Company
# 1      Full-Time ∙ Internship  Auto-Owners Insurance Company
# 2             Full-Time ∙ Job              SCC Soft Computer
# 3             Full-Time ∙ Job              SCC Soft Computer
# 4      Part-Time ∙ Internship                   Coding4Youth
# ...                       ...                            ...
# 19442  Full-Time ∙ Internship                  Camp Skylemar
# 19443  Full-Time ∙ Internship                  Camp Skylemar
# 19444  Full-Time ∙ Internship                         CONMED
# 19445  Full-Time ∙ Internship                    Camp Danbee
# 19446  Full-Time ∙ Internship                    Camp Danbee
#
#                                         Company Location        Employees  \
# 0      Lakeland, FL\nIrmo, SC\nForest, VA\nLexington,...   5,000 - 10,000
# 1      Lakeland, FL\nIrmo, SC\nCharlotte, NC\nForest,...   5,000 - 10,000
# 2                                         Clearwater, FL      250 - 1,000
# 3                                         Clearwater, FL      250 - 1,000
# 4      Atlanta, GA\nHouston, TX\nPhiladelphia, PA\nCh...  10,000 - 25,000
# ...                                                  ...              ...
# 19442                                         Naples, ME        100 - 250
# 19443                                         Naples, ME        100 - 250
# 19444                                          Tampa, FL    1,000 - 5,000
# 19445                                           Peru, MA      250 - 1,000
# 19446                                           Peru, MA      250 - 1,000
#
#                               Industry  \
# 0                            Insurance
# 1                            Insurance
# 2                  Internet & Software
# 3                  Internet & Software
# 4                      Other Education
# ...                                ...
# 19442                 Sports & Leisure
# 19443                 Sports & Leisure
# 19444                  Medical Devices
# 19445  Summer Camps/Outdoor Recreation
# 19446  Summer Camps/Outdoor Recreation
#
#                                             Headquarters Posted date  \
# 0                                            Lansing, MI  2016-07-13
# 1                                            Lansing, MI  2016-07-13
# 2                                         Clearwater, FL  2016-08-22
# 3                                         Clearwater, FL  2016-08-22
# 4                                           San Jose, CA  2016-09-19
# ...                                                  ...         ...
# 19442                                         Naples, ME  2023-03-12
# 19443                                         Naples, ME  2023-03-12
# 19444                                          Largo, FL  2023-03-12
# 19445  101 W Main Rd, Peru, Massachusetts 01235, Unit...  2023-03-12
# 19446  101 W Main Rd, Peru, Massachusetts 01235, Unit...  2023-03-12
#
#       Location type                         US work authorization  \
# 0           On-site                                      Required
# 1           On-site                                      Required
# 2           On-site                                      Required
# 3           On-site                                      Required
# 4            Remote                                      Required
# ...             ...                                           ...
# 19442       On-site                               Accepts OPT/CPT
# 19443       On-site                               Accepts OPT/CPT
# 19444        Remote                                      Required
# 19445       On-site  Will sponsor a work visa and accepts OPT/CPT
# 19446       On-site  Will sponsor a work visa and accepts OPT/CPT
#
#                 Estimated pay        Seasonal role Company division  \
# 0                         NaN                  NaN              NaN
# 1                         NaN                  NaN              NaN
# 2             $19.00 per hour                  NaN              NaN
# 3             $18.00 per hour                  NaN              NaN
# 4             $20.00 per hour   (6/5/17 - 9/12/90)              NaN
# ...                       ...                  ...              ...
# 19442         $3,000 per year   (6/11/23 - 8/6/23)              NaN
# 19443         $3,500 per year   (6/13/23 - 8/7/23)              NaN
# 19444   $15.00-20.00 per hour                  NaN              NaN
# 19445  $1,000-2,000 per month  (6/15/23 - 8/11/23)              NaN
# 19446  $2,000-3,000 per month   (6/9/23 - 8/11/23)              NaN
#
#       Work study Application deadline (date) Application deadline (time)  \
# 0            NaN                  2023-04-04                    15:30:00
# 1            NaN                  2023-04-04                    15:30:00
# 2            NaN                  2023-03-13                    00:00:00
# 3            NaN                  2023-03-13                    00:00:00
# 4            NaN                  2050-09-29                    21:31:00
# ...          ...                         ...                         ...
# 19442        NaN                  2023-04-22                    00:00:00
# 19443        NaN                  2023-04-29                    00:00:00
# 19444        NaN                  2023-03-31                    00:00:00
# 19445        NaN                  2023-04-30                    12:00:00
# 19446        NaN                  2023-04-30                    12:00:00
#
#        Application Window (weeks)
# 0                             350
# 1                             350
# 2                             342
# 3                             342
# 4                            1775
# ...                           ...
# 19442                           5
# 19443                           6
# 19444                           2
# 19445                           7
# 19446                           7
#
# [19447 rows x 17 columns]

# %% [markdown]
# Job Type

# %%
# split the job_type column into two separate columns based on the " ∙ " separator
df_modify[['Employment Type', 'Job Type', "Payment Status"]] = df_modify['Job Info'].str.split(' ∙ ', expand=True)

# Modify the 'Payment Status' column to contain boolean values indicating if the job is paid or unpaid
df_modify['Payment Status'] = df_modify['Estimated pay'].apply(lambda x: 'Paid' if pd.notnull(x) else 'Unpaid')

# drop the original job_type column
df_modify.drop('Job Info', axis=1, inplace=True)

# %% [markdown]
# Location

# %%
# Caluclate the number of company locations based on the "\n" separator, if row contains one, else use 1
df_modify['Number of Location'] = df_modify['Company Location'].apply(lambda x: x.count('\n') + 1 if '\n' in x else 1)
#Replace '\n' with ' ' if 'Company Location' row contains one, else keep row without changes
df_modify['Company Location'] = df_modify['Company Location'].apply(lambda x: x.replace('\n', ' ') if '\n' in x else x)

# %% [markdown]
# Seasonal Role

# %%
# create role_start_date and role_end_date columns from seasonal_role
df_modify[['Role start date', 'Role end date']] = df_modify['Seasonal role'].str.split(' - ', expand=True)

# Remove the brackets from 'Role start date' and 'Role end date'
df_modify['Role start date'] = df_modify['Role start date'].str.replace('(','')
df_modify['Role end date'] = df_modify['Role end date'].str.replace(')','')

# Convert 'Role start date' and 'Role end date' to datetime format
df_modify['Role start date'] = pd.to_datetime(df_modify['Role start date'])
df_modify['Role end date'] = pd.to_datetime(df_modify['Role end date'])

df_modify['Role Duration'] = (df_modify['Role end date'] - df_modify['Role start date']).dt.days
# Convert Role Duration from days to weeks
df_modify['Role Duration (weeks)'] = df_modify['Role Duration'].apply(lambda x: math.ceil(x/7) if pd.notna(x) else None)

# modify seasonal_role column to contain boolean values
df_modify['Seasonal role'] = df_modify['Seasonal role'].notna()

df_modify.drop('Role Duration', axis=1, inplace=True)
# Out:
# C:\Users\owner\AppData\Local\Temp\ipykernel_20752\579819673.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_modify['Role start date'] = df_modify['Role start date'].str.replace('(','')
# C:\Users\owner\AppData\Local\Temp\ipykernel_20752\579819673.py:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_modify['Role end date'] = df_modify['Role end date'].str.replace(')','')

# %%
df_modify.tail(15)
# Out:
#                                                Job Title  \
# 19432         Resource Team Intern Summer 2023 (Spanish)
# 19433            Respite Counselor - Milford - Full Time
# 19434               Respite Counselor - Milford - Relief
# 19435                        Respite Counselor - Norwood
# 19436               Respite Counselor - Norwood - Relief
# 19437                    Social Media Intern Summer 2023
# 19438  Taxpayer Advocate Service (TAS) - Case Advocat...
# 19439  Taxpayer Advocate Service (TAS) - Case Advocat...
# 19440  Taxpayer Advocate Service (TAS) - Intake Advoc...
# 19441  Taxpayer Advocate Service (TAS) - Intake Advoc...
# 19442                   Coaching Assistant - Summer camp
# 19443                       Videographer/Content Creator
# 19444                 Talent Acquisition Intern - Remote
# 19445                       Camp Counselor - Summer 2023
# 19446  Outdoor Adventure & Ropes Instructor - Summer ...
#
#                                             Company Name  \
# 19432                   InReach (formerly AsylumConnect)
# 19433                     Riverside Community Care, Inc.
# 19434                     Riverside Community Care, Inc.
# 19435                     Riverside Community Care, Inc.
# 19436                     Riverside Community Care, Inc.
# 19437                   InReach (formerly AsylumConnect)
# 19438  Taxpayer Advocate Service - Internal Revenue S...
# 19439  Taxpayer Advocate Service - Internal Revenue S...
# 19440  Taxpayer Advocate Service - Internal Revenue S...
# 19441  Taxpayer Advocate Service - Internal Revenue S...
# 19442                                      Camp Skylemar
# 19443                                      Camp Skylemar
# 19444                                             CONMED
# 19445                                        Camp Danbee
# 19446                                        Camp Danbee
#
#                                         Company Location      Employees  \
# 19432  Miami, FL Atlanta, GA Asheville, NC Nashville,...         1 - 10
# 19433                                        Milford, MA  1,000 - 5,000
# 19434                                        Milford, MA  1,000 - 5,000
# 19435                                        Norwood, MA  1,000 - 5,000
# 19436                                        Norwood, MA  1,000 - 5,000
# 19437  Miami, FL New Orleans, LA Washington, DC India...         1 - 10
# 19438                                      United States        25,000+
# 19439                                      United States        25,000+
# 19440                                      United States        25,000+
# 19441                                      United States        25,000+
# 19442                                         Naples, ME      100 - 250
# 19443                                         Naples, ME      100 - 250
# 19444                                          Tampa, FL  1,000 - 5,000
# 19445                                           Peru, MA    250 - 1,000
# 19446                                           Peru, MA    250 - 1,000
#
#                                   Industry  \
# 19432                   Non-Profit - Other
# 19433                           Healthcare
# 19434                           Healthcare
# 19435                           Healthcare
# 19436                           Healthcare
# 19437                   Non-Profit - Other
# 19438  Government - Local, State & Federal
# 19439  Government - Local, State & Federal
# 19440  Government - Local, State & Federal
# 19441  Government - Local, State & Federal
# 19442                     Sports & Leisure
# 19443                     Sports & Leisure
# 19444                      Medical Devices
# 19445      Summer Camps/Outdoor Recreation
# 19446      Summer Camps/Outdoor Recreation
#
#                                             Headquarters Posted date  \
# 19432  228 Park Ave S Suite # 90945 New York, NY 1000...  2023-03-11
# 19433  270 Bridge Street, Suite 301, Dedham, Massachu...  2023-03-11
# 19434  270 Bridge Street, Suite 301, Dedham, Massachu...  2023-03-11
# 19435  270 Bridge Street, Suite 301, Dedham, Massachu...  2023-03-11
# 19436  270 Bridge Street, Suite 301, Dedham, Massachu...  2023-03-11
# 19437  228 Park Ave S Suite # 90945 New York, NY 1000...  2023-03-11
# 19438                                  Laguna Niguel, CA  2023-03-11
# 19439                                  Laguna Niguel, CA  2023-03-11
# 19440                                  Laguna Niguel, CA  2023-03-11
# 19441                                  Laguna Niguel, CA  2023-03-11
# 19442                                         Naples, ME  2023-03-12
# 19443                                         Naples, ME  2023-03-12
# 19444                                          Largo, FL  2023-03-12
# 19445  101 W Main Rd, Peru, Massachusetts 01235, Unit...  2023-03-12
# 19446  101 W Main Rd, Peru, Massachusetts 01235, Unit...  2023-03-12
#
#       Location type                         US work authorization  \
# 19432        Remote                                      Required
# 19433       On-site                                      Required
# 19434       On-site                                      Required
# 19435       On-site                                      Required
# 19436       On-site                                      Required
# 19437        Remote                                      Required
# 19438        Remote                                      Required
# 19439       On-site                                      Required
# 19440        Remote                                      Required
# 19441        Remote                                      Required
# 19442       On-site                               Accepts OPT/CPT
# 19443       On-site                               Accepts OPT/CPT
# 19444        Remote                                      Required
# 19445       On-site  Will sponsor a work visa and accepts OPT/CPT
# 19446       On-site  Will sponsor a work visa and accepts OPT/CPT
#
#                  Estimated pay  ...  Application deadline (date)  \
# 19432                      NaN  ...                   2023-05-08
# 19433                      NaN  ...                   2023-08-31
# 19434                      NaN  ...                   2023-08-31
# 19435                      NaN  ...                   2023-08-31
# 19436                      NaN  ...                   2023-08-31
# 19437                      NaN  ...                   2023-05-08
# 19438  $30,000-40,000 per year  ...                   2023-10-11
# 19439  $30,000-40,000 per year  ...                   2023-09-27
# 19440  $30,000-40,000 per year  ...                   2023-09-26
# 19441  $30,000-40,000 per year  ...                   2023-09-20
# 19442          $3,000 per year  ...                   2023-04-22
# 19443          $3,500 per year  ...                   2023-04-29
# 19444    $15.00-20.00 per hour  ...                   2023-03-31
# 19445   $1,000-2,000 per month  ...                   2023-04-30
# 19446   $2,000-3,000 per month  ...                   2023-04-30
#
#       Application deadline (time) Application Window (weeks) Employment Type  \
# 19432                    17:00:00                          8       Part-Time
# 19433                    00:00:00                         24       Full-Time
# 19434                    00:00:00                         24       Part-Time
# 19435                    00:00:00                         24       Full-Time
# 19436                    00:00:00                         24       Part-Time
# 19437                    17:00:00                          8       Part-Time
# 19438                    02:00:00                         30       Full-Time
# 19439                    02:00:00                         28       Full-Time
# 19440                    02:00:00                         28       Full-Time
# 19441                    02:00:00                         27       Full-Time
# 19442                    00:00:00                          5       Full-Time
# 19443                    00:00:00                          6       Full-Time
# 19444                    00:00:00                          2       Full-Time
# 19445                    12:00:00                          7       Full-Time
# 19446                    12:00:00                          7       Full-Time
#
#          Job Type  Payment Status Number of Location Role start date  \
# 19432  Internship          Unpaid                 20      2023-05-22
# 19433         Job          Unpaid                  1             NaT
# 19434         Job          Unpaid                  1             NaT
# 19435         Job          Unpaid                  1             NaT
# 19436         Job          Unpaid                  1             NaT
# 19437  Internship          Unpaid                 12      2023-05-22
# 19438         Job            Paid                  1             NaT
# 19439         Job            Paid                  1             NaT
# 19440         Job            Paid                  1             NaT
# 19441         Job            Paid                  1             NaT
# 19442  Internship            Paid                  1      2023-06-11
# 19443  Internship            Paid                  1      2023-06-13
# 19444  Internship            Paid                  1             NaT
# 19445  Internship            Paid                  1      2023-06-15
# 19446  Internship            Paid                  1      2023-06-09
#
#       Role end date  Role Duration (weeks)
# 19432    2023-08-11                   12.0
# 19433           NaT                    NaN
# 19434           NaT                    NaN
# 19435           NaT                    NaN
# 19436           NaT                    NaN
# 19437    2023-08-11                   12.0
# 19438           NaT                    NaN
# 19439           NaT                    NaN
# 19440           NaT                    NaN
# 19441           NaT                    NaN
# 19442    2023-08-06                    8.0
# 19443    2023-08-07                    8.0
# 19444           NaT                    NaN
# 19445    2023-08-11                    9.0
# 19446    2023-08-11                    9.0
#
# [15 rows x 23 columns]

# %% [markdown]
# Estimated Salary

# %%
# Split the 'Estimated pay' column into two separate columns 'Pay rate' and 'Payment Period' based on the separator 'per'
df_modify[['Pay rate','Payment Period']] = df_modify['Estimated pay'].str.split('per', expand=True)

# Strip any leading or trailing white spaces in the 'Payment Period' column
df_modify['Payment Period'] = df_modify['Payment Period'].str.strip()


# Remove the dollar sign '$' from the 'Pay rate' column
df_modify['Pay rate'] = df_modify['Pay rate'].str.replace('$','')

# Extract the minimum and maximum salary values from the 'Pay rate' column and store them in new columns 'Min salary' and 'Max salary', respectively
df_modify['Min salary'] = df_modify['Pay rate'].apply(lambda x: x.split('-')[0].strip() if isinstance(x, str) and '-' in x else None)
df_modify['Max salary'] = df_modify['Pay rate'].apply(lambda x: x.split('-')[1].strip() if isinstance(x, str) and '-' in x and len(x.split('-')) >= 2 else None)
df_modify['Min salary'] = df_modify['Pay rate'].apply(lambda x: x.split('-')[0].strip().replace(',', '') if isinstance(x, str) else None)
df_modify['Max salary'] = df_modify['Pay rate'].apply(lambda x: x.split('-')[1].strip().replace(',', '') if isinstance(x, str) and '-' in x else None)

# Convert the 'Min salary' and 'Max salary' columns to numeric data types
df_modify['Min salary'] = pd.to_numeric(df_modify['Min salary'])
df_modify['Max salary'] = pd.to_numeric(df_modify['Max salary'])

# Fill any missing values in the 'Max salary' column with the corresponding value from the 'Min salary' column
df_modify['Max salary'].fillna(df_modify['Min salary'], inplace=True)

# Drop the original 'Estimated pay' column from the DataFrame using the drop() method with axis=1, inplace=True
df_modify.drop('Estimated pay', axis=1, inplace=True)
# Out:
# C:\Users\owner\AppData\Local\Temp\ipykernel_20752\1559040928.py:9: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_modify['Pay rate'] = df_modify['Pay rate'].str.replace('$','')

# %% [markdown]
# Work study

# %%
#Drop the 'Work study' column from the dataframe.
df_modify.drop('Work study', axis=1, inplace=True)

# %%
df_modify.tail(10)
# Out:
#                                                Job Title  \
# 19437                    Social Media Intern Summer 2023
# 19438  Taxpayer Advocate Service (TAS) - Case Advocat...
# 19439  Taxpayer Advocate Service (TAS) - Case Advocat...
# 19440  Taxpayer Advocate Service (TAS) - Intake Advoc...
# 19441  Taxpayer Advocate Service (TAS) - Intake Advoc...
# 19442                   Coaching Assistant - Summer camp
# 19443                       Videographer/Content Creator
# 19444                 Talent Acquisition Intern - Remote
# 19445                       Camp Counselor - Summer 2023
# 19446  Outdoor Adventure & Ropes Instructor - Summer ...
#
#                                             Company Name  \
# 19437                   InReach (formerly AsylumConnect)
# 19438  Taxpayer Advocate Service - Internal Revenue S...
# 19439  Taxpayer Advocate Service - Internal Revenue S...
# 19440  Taxpayer Advocate Service - Internal Revenue S...
# 19441  Taxpayer Advocate Service - Internal Revenue S...
# 19442                                      Camp Skylemar
# 19443                                      Camp Skylemar
# 19444                                             CONMED
# 19445                                        Camp Danbee
# 19446                                        Camp Danbee
#
#                                         Company Location      Employees  \
# 19437  Miami, FL New Orleans, LA Washington, DC India...         1 - 10
# 19438                                      United States        25,000+
# 19439                                      United States        25,000+
# 19440                                      United States        25,000+
# 19441                                      United States        25,000+
# 19442                                         Naples, ME      100 - 250
# 19443                                         Naples, ME      100 - 250
# 19444                                          Tampa, FL  1,000 - 5,000
# 19445                                           Peru, MA    250 - 1,000
# 19446                                           Peru, MA    250 - 1,000
#
#                                   Industry  \
# 19437                   Non-Profit - Other
# 19438  Government - Local, State & Federal
# 19439  Government - Local, State & Federal
# 19440  Government - Local, State & Federal
# 19441  Government - Local, State & Federal
# 19442                     Sports & Leisure
# 19443                     Sports & Leisure
# 19444                      Medical Devices
# 19445      Summer Camps/Outdoor Recreation
# 19446      Summer Camps/Outdoor Recreation
#
#                                             Headquarters Posted date  \
# 19437  228 Park Ave S Suite # 90945 New York, NY 1000...  2023-03-11
# 19438                                  Laguna Niguel, CA  2023-03-11
# 19439                                  Laguna Niguel, CA  2023-03-11
# 19440                                  Laguna Niguel, CA  2023-03-11
# 19441                                  Laguna Niguel, CA  2023-03-11
# 19442                                         Naples, ME  2023-03-12
# 19443                                         Naples, ME  2023-03-12
# 19444                                          Largo, FL  2023-03-12
# 19445  101 W Main Rd, Peru, Massachusetts 01235, Unit...  2023-03-12
# 19446  101 W Main Rd, Peru, Massachusetts 01235, Unit...  2023-03-12
#
#       Location type                         US work authorization  \
# 19437        Remote                                      Required
# 19438        Remote                                      Required
# 19439       On-site                                      Required
# 19440        Remote                                      Required
# 19441        Remote                                      Required
# 19442       On-site                               Accepts OPT/CPT
# 19443       On-site                               Accepts OPT/CPT
# 19444        Remote                                      Required
# 19445       On-site  Will sponsor a work visa and accepts OPT/CPT
# 19446       On-site  Will sponsor a work visa and accepts OPT/CPT
#
#        Seasonal role  ...    Job Type Payment Status Number of Location  \
# 19437           True  ...  Internship         Unpaid                 12
# 19438          False  ...         Job           Paid                  1
# 19439          False  ...         Job           Paid                  1
# 19440          False  ...         Job           Paid                  1
# 19441          False  ...         Job           Paid                  1
# 19442           True  ...  Internship           Paid                  1
# 19443           True  ...  Internship           Paid                  1
# 19444          False  ...  Internship           Paid                  1
# 19445           True  ...  Internship           Paid                  1
# 19446           True  ...  Internship           Paid                  1
#
#        Role start date Role end date Role Duration (weeks)        Pay rate  \
# 19437       2023-05-22    2023-08-11                  12.0             NaN
# 19438              NaT           NaT                   NaN  30,000-40,000
# 19439              NaT           NaT                   NaN  30,000-40,000
# 19440              NaT           NaT                   NaN  30,000-40,000
# 19441              NaT           NaT                   NaN  30,000-40,000
# 19442       2023-06-11    2023-08-06                   8.0          3,000
# 19443       2023-06-13    2023-08-07                   8.0          3,500
# 19444              NaT           NaT                   NaN    15.00-20.00
# 19445       2023-06-15    2023-08-11                   9.0    1,000-2,000
# 19446       2023-06-09    2023-08-11                   9.0    2,000-3,000
#
#        Payment Period Min salary Max salary
# 19437             NaN        NaN        NaN
# 19438            year    30000.0    40000.0
# 19439            year    30000.0    40000.0
# 19440            year    30000.0    40000.0
# 19441            year    30000.0    40000.0
# 19442            year     3000.0     3000.0
# 19443            year     3500.0     3500.0
# 19444            hour       15.0       20.0
# 19445           month     1000.0     2000.0
# 19446           month     2000.0     3000.0
#
# [10 rows x 25 columns]

# %% [markdown]
# ***EXTRA FEATURES***

# %%
df_modify.columns
# Out:
# Index(['Job Title', 'Company Name', 'Company Location', 'Employees',
#        'Industry', 'Headquarters', 'Posted date', 'Location type',
#        'US work authorization', 'Seasonal role', 'Company division',
#        'Application deadline (date)', 'Application deadline (time)',
#        'Application Window (weeks)', 'Employment Type', 'Job Type',
#        'Payment Status', 'Number of Location', 'Role start date',
#        'Role end date', 'Role Duration (weeks)', 'Pay rate', 'Payment Period',
#        'Min salary', 'Max salary'],
#       dtype='object')

# %%
#Method to convert monthly/hourly pay to yearly
def convert_salary(df):
    for index, row in df.iterrows():
        if row['Payment Period'] == 'hour':
            df.at[index, 'Min salary'] *= 2080
            df.at[index, 'Max salary'] *= 2080
            df.at[index, 'Payment Period'] = 'year'
        elif row['Payment Period'] == 'month':
            df.at[index, 'Min salary'] *= 12
            df.at[index, 'Max salary'] *= 12
            df.at[index, 'Payment Period'] = 'year'
    return df

# %%
#Aplly method convert_salary()
df_modify = convert_salary(df_modify)

# %% [markdown]
# ***STEP 2: DATA CLEANING***

# %% [markdown]
# Explore modified dataframe

# %%
df_modify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19447 entries, 0 to 19446
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Job Title                    19447 non-null  object
#  1   Company Name                 19447 non-null  object
#  2   Company Location             19447 non-null  object
#  3   Employees                    19447 non-null  object
#  4   Industry                     19447 non-null  object
#  5   Headquarters                 19442 non-null  object
#  6   Posted date                  19447 non-null  datetime64[ns]
#  7   Location type                19447 non-null  object
#  8   US work authorization        19244 non-null  object
#  9   Seasonal role                19447 non-null  bool
#  10  Company division             3220 non-null   object
#  11  Application deadline (date)  19447 non-null  datetime64[ns]
#  12  Application deadline (time)  19447 non-null  object
#  13  Application Window (weeks)   19447 non-null  int64
#  14  Employment Type              19447 non-null  object
#  15  Job Type                     19447 non-null  object
#  16  Payment Status               19447 non-null  object
#  17  Number of Location           19447 non-null  int64
#  18  Role start date              4530 non-null   datetime64[ns]
#  19  Role end date                4530 non-null   datetime64[ns]
#  20  Role Duration (weeks)        4530 non-null   float64
#  21  Pay rate                     11334 non-null  object
#  22  Payment Period               11334 non-null  object
#  23  Min salary                   11334 non-null  float64
#  24  Max salary                   11334 non-null  float64
# dtypes: bool(1), datetime64[ns](4), float64(3), int64(2), object(15)
# memory usage: 3.6+ MB

# %%
df_modify.describe()
# Out:
#        Application Window (weeks)  Number of Location  Role Duration (weeks)  \
# count                19447.000000        19447.000000            4530.000000
# mean                    40.375071            2.011210              21.090949
# std                     93.379761            6.797362              48.847758
# min                   -671.000000            1.000000           -1394.000000
# 25%                      7.000000            1.000000              10.000000
# 50%                     24.000000            1.000000              12.000000
# 75%                     47.000000            1.000000              19.000000
# max                   4173.000000          322.000000            1601.000000
#
#          Min salary    Max salary
# count  1.133400e+04  1.133400e+04
# mean   6.135175e+05  7.459431e+05
# std    1.095104e+07  1.256966e+07
# min    1.000000e+00  1.000000e+00
# 25%    3.120000e+04  3.600000e+04
# 50%    4.160000e+04  5.000000e+04
# 75%    6.000000e+04  7.000000e+04
# max    8.320000e+08  8.320000e+08

# %%
df_modify.shape
# Out:
# (19447, 25)

# %%
df_modify.nunique()
# Out:
# Job Title                      16776
# Company Name                    4953
# Company Location                4395
# Employees                         10
# Industry                          74
# Headquarters                    2672
# Posted date                      958
# Location type                      2
# US work authorization              5
# Seasonal role                      2
# Company division                1067
# Application deadline (date)      697
# Application deadline (time)      305
# Application Window (weeks)       380
# Employment Type                    3
# Job Type                           8
# Payment Status                     2
# Number of Location                74
# Role start date                  431
# Role end date                    453
# Role Duration (weeks)            139
# Pay rate                        2659
# Payment Period                     2
# Min salary                      1774
# Max salary                      1872
# dtype: int64

# %% [markdown]
# Find duplicates

# %%
#Drop rows with duplicated values
df_modify.drop_duplicates(inplace=True)

# %%
#Check number of duplicates
df_modify.duplicated().value_counts()
# Out:
# False    19447
# dtype: int64

# %% [markdown]
# Empoyment type

# %%
df_modify['Employment Type'].unique()
# Out:
# array(['Full-Time', 'Part-Time', 'Seasonal'], dtype=object)

# %%
filt1 = (df_modify['Employment Type']=='Seasonal')
df_modify.loc[filt1,['Employment Type','Seasonal role']].value_counts()
# Out:
# Employment Type  Seasonal role
# Seasonal         True             1
# dtype: int64

# %%
df_modify.drop(df[filt1].index, inplace=True)

# %% [markdown]
# Payment Period

# %%
df_modify['Payment Period'].unique()
# Out:
# array([nan, 'year', 'year or more'], dtype=object)

# %%
# Assign NaN to the "Max value" column where "Payment period" is "year or more"
df_modify.loc[df_modify['Payment Period'] == 'year or more', 'Max salary'] = np.nan

# %% [markdown]
# Role Duration (weeks)

# %%
df_modify.drop(df_modify[df_modify['Role Duration (weeks)'] < 0].index, inplace=True)

# %% [markdown]
# Application deadline

# %%
df_modify.drop(df_modify[df_modify['Application Window (weeks)'] < 0].index, inplace=True)

# %% [markdown]
# ***STEP 3: SAVE NEW (COMPLETE) DATAFRAME TO .csv FILE***

# %%
print(df.columns)
print("_________________________")
print(df_modify.columns)
print("_________________________")
print(df_modify.shape)
# Out:
# Index(['Job Title', 'Job Info', 'Company Name', 'Company Location',
#        'Employees', 'Industry', 'Headquarters', 'Application deadline',
#        'Posted date', 'Location type', 'US work authorization',
#        'Estimated pay', 'Seasonal role', 'Company division', 'Work study'],
#       dtype='object')
# _________________________
# Index(['Job Title', 'Company Name', 'Company Location', 'Employees',
#        'Industry', 'Headquarters', 'Posted date', 'Location type',
#        'US work authorization', 'Seasonal role', 'Company division',
#        'Application deadline (date)', 'Application deadline (time)',
#        'Application Window (weeks)', 'Employment Type', 'Job Type',
#        'Payment Status', 'Number of Location', 'Role start date',
#        'Role end date', 'Role Duration (weeks)', 'Pay rate', 'Payment Period',
#        'Min salary', 'Max salary'],
#       dtype='object')
# _________________________
# (19438, 25)

# %%
df_modify = df_modify[['Job Title',
                       'Company Name',
                       'Industry',
                       'Company division',
                       
                       'Posted date',
                       'Application deadline (date)', 
                       'Application deadline (time)',
                       'Application Window (weeks)',

                       'Employment Type',
                       'Job Type',
                       'Location type', 

                       'US work authorization',

                       'Seasonal role',
                       'Role start date', 
                       'Role end date',
                       'Role Duration (weeks)',

                       'Payment Status',
                       'Payment Period',
                       'Pay rate', 
                       'Min salary', 
                       'Max salary',

                       'Headquarters',
                       'Company Location',
                       'Number of Location',

                       'Employees'
                       ]]

# %% [markdown]
# Data Dictionary for modified table (modified_data.csv)
#
# * **Job Title**: The title of the job position being advertised.
# * **Company Name**: The name of the company offering the job.
# * **Industry**: The industry in which the company operates.
# * **Company division**: The division of the company that is offering the job.
# * **Posted date**: The date on which the job was posted.
# * **Application deadline (date)**: The date by which job applications must be submitted.
# * **Application deadline (time)**: The time of day by which job applications must be submitted.
# * **Application Window (weeks)**: The time period between the job being posted and the application deadline (weeks).
# * **Employment Type**: Whether the job is full-time, part-time, or some other type of employment.
# * **Job Type**: Whether the job is a job or an internship.
# * **Location type**: Whether the job is on-site or remote.
# * **US work authorization**: Whether the company requires candidates to have US work authorization.
# * **Seasonal role**: Whether the job is a seasonal role.
# * **Role start date**: The date on which the seasonal role starts.
# * **Role end date**: The date on which the seasonal role ends.
# * **Role Duration (weeks)**: Describer the number of weeks to work, for esonal roles
# * **Payment Status**: Whether the job is paid or unpaid.
# * **Payment Period**: Describes the period for payment in the job posting (year/year or more).
# * **Pay rate**: The rate at which the job pays.
# * **Min salary**: The minimum salary for the job.
# * **Max salary**: The maximum salary for the job.
# * **Headquarters**: The location of the company's headquarters.
# * **Company Location**: The location of the company offering the job.
# * **Number of Location**: The number of locations where the company has offices.
# * **Employees**: Information about the size of the company, such as the number of employees

# %%
df_modify.head()
# Out:
#                                            Job Title  \
# 0                  Entry Level Insurance Underwriter
# 1                                        Internships
# 2  Blood Bank Associate Technical Support Specialist
# 3     Lab/Mic Associate Technical Support Specialist
# 5       Instructional Design and Delivery Internship
#
#                     Company Name             Industry Company division  \
# 0  Auto-Owners Insurance Company            Insurance              NaN
# 1  Auto-Owners Insurance Company            Insurance              NaN
# 2              SCC Soft Computer  Internet & Software              NaN
# 3              SCC Soft Computer  Internet & Software              NaN
# 5                 24/7 Education       K-12 Education              NaN
#
#   Posted date Application deadline (date) Application deadline (time)  \
# 0  2016-07-13                  2023-04-04                    15:30:00
# 1  2016-07-13                  2023-04-04                    15:30:00
# 2  2016-08-22                  2023-03-13                    00:00:00
# 3  2016-08-22                  2023-03-13                    00:00:00
# 5  2016-09-26                  2023-12-11                    00:00:00
#
#    Application Window (weeks) Employment Type    Job Type  ...  \
# 0                         350       Full-Time         Job  ...
# 1                         350       Full-Time  Internship  ...
# 2                         342       Full-Time         Job  ...
# 3                         342       Full-Time         Job  ...
# 5                         376       Part-Time  Internship  ...
#
#   Role Duration (weeks) Payment Status  Payment Period Pay rate Min salary  \
# 0                   NaN         Unpaid             NaN      NaN        NaN
# 1                   NaN         Unpaid             NaN      NaN        NaN
# 2                   NaN           Paid            year   19.00     39520.0
# 3                   NaN           Paid            year   18.00     37440.0
# 5                 185.0         Unpaid             NaN      NaN        NaN
#
#    Max salary       Headquarters  \
# 0         NaN        Lansing, MI
# 1         NaN        Lansing, MI
# 2     39520.0     Clearwater, FL
# 3     37440.0     Clearwater, FL
# 5         NaN  New York City, NY
#
#                                     Company Location Number of Location  \
# 0  Lakeland, FL Irmo, SC Forest, VA Lexington, KY...                 18
# 1  Lakeland, FL Irmo, SC Charlotte, NC Forest, VA...                 20
# 2                                     Clearwater, FL                  1
# 3                                     Clearwater, FL                  1
# 5                                       New York, NY                  1
#
#         Employees
# 0  5,000 - 10,000
# 1  5,000 - 10,000
# 2     250 - 1,000
# 3     250 - 1,000
# 5         10 - 50
#
# [5 rows x 25 columns]

# %%
df_modify.to_csv('modified_data.csv', index=False)
